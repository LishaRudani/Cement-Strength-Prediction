# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
data = pd.read_csv(r'C:\Users\Lenovo\Desktop\cement\Concrete_Data.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Cement            1030 non-null   float64
#  1   Slag              1030 non-null   float64
#  2   Flyash            1030 non-null   float64
#  3   Water             1030 non-null   float64
#  4   SuperPlasticizer  1030 non-null   float64
#  5   CoarseAggregate   1030 non-null   float64
#  6   FineAggregate     1030 non-null   float64
#  7   Age               1030 non-null   int64
#  8   CSinMPa           1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
data.describe()
# Out:
#             Cement         Slag       Flyash        Water  SuperPlasticizer  \
# count  1030.000000  1030.000000  1030.000000  1030.000000       1030.000000
# mean    281.167864    73.895825    54.188350   181.567282          6.204660
# std     104.506364    86.279342    63.997004    21.354219          5.973841
# min     102.000000     0.000000     0.000000   121.800000          0.000000
# 25%     192.375000     0.000000     0.000000   164.900000          0.000000
# 50%     272.900000    22.000000     0.000000   185.000000          6.400000
# 75%     350.000000   142.950000   118.300000   192.000000         10.200000
# max     540.000000   359.400000   200.100000   247.000000         32.200000
#
#        CoarseAggregate  FineAggregate          Age      CSinMPa
# count      1030.000000    1030.000000  1030.000000  1030.000000
# mean        972.918932     773.580485    45.662136    35.817961
# std          77.753954      80.175980    63.169912    16.705742
# min         801.000000     594.000000     1.000000     2.330000
# 25%         932.000000     730.950000     7.000000    23.710000
# 50%         968.000000     779.500000    28.000000    34.445000
# 75%        1029.400000     824.000000    56.000000    46.135000
# max        1145.000000     992.600000   365.000000    82.600000

# %%
data.shape
# Out:
# (1030, 9)

# %%
data.isnull().sum()
# Out:
# Cement              0
# Slag                0
# Flyash              0
# Water               0
# SuperPlasticizer    0
# CoarseAggregate     0
# FineAggregate       0
# Age                 0
# CSinMPa             0
# dtype: int64

# %%
data.corr()
# Out:
#                     Cement      Slag    Flyash     Water  SuperPlasticizer  \
# Cement            1.000000 -0.275216 -0.397467 -0.081587          0.092386
# Slag             -0.275216  1.000000 -0.323580  0.107252          0.043270
# Flyash           -0.397467 -0.323580  1.000000 -0.256984          0.377503
# Water            -0.081587  0.107252 -0.256984  1.000000         -0.657533
# SuperPlasticizer  0.092386  0.043270  0.377503 -0.657533          1.000000
# CoarseAggregate  -0.109349 -0.283999 -0.009961 -0.182294         -0.265999
# FineAggregate    -0.222718 -0.281603  0.079108 -0.450661          0.222691
# Age               0.081946 -0.044246 -0.154371  0.277618         -0.192700
# CSinMPa           0.497832  0.134829 -0.105755 -0.289633          0.366079
#
#                   CoarseAggregate  FineAggregate       Age   CSinMPa
# Cement                  -0.109349      -0.222718  0.081946  0.497832
# Slag                    -0.283999      -0.281603 -0.044246  0.134829
# Flyash                  -0.009961       0.079108 -0.154371 -0.105755
# Water                   -0.182294      -0.450661  0.277618 -0.289633
# SuperPlasticizer        -0.265999       0.222691 -0.192700  0.366079
# CoarseAggregate          1.000000      -0.178481 -0.003016 -0.164935
# FineAggregate           -0.178481       1.000000 -0.156095 -0.167241
# Age                     -0.003016      -0.156095  1.000000  0.328873
# CSinMPa                 -0.164935      -0.167241  0.328873  1.000000

# %%
plt.figure(figsize=(8,4))
sns.heatmap(data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
data.columns
# Out:
# Index(['Cement', 'Slag', 'Flyash', 'Water', 'SuperPlasticizer',
#        'CoarseAggregate', 'FineAggregate', 'Age', 'CSinMPa'],
#       dtype='object')

# %%
data.head
# Out:
# <bound method NDFrame.head of       Cement   Slag  Flyash  Water  SuperPlasticizer  CoarseAggregate  \
# 0      540.0    0.0     0.0  162.0               2.5           1040.0
# 1      540.0    0.0     0.0  162.0               2.5           1055.0
# 2      332.5  142.5     0.0  228.0               0.0            932.0
# 3      332.5  142.5     0.0  228.0               0.0            932.0
# 4      198.6  132.4     0.0  192.0               0.0            978.4
# ...      ...    ...     ...    ...               ...              ...
# 1025   276.4  116.0    90.3  179.6               8.9            870.1
# 1026   322.2    0.0   115.6  196.0              10.4            817.9
# 1027   148.5  139.4   108.6  192.7               6.1            892.4
# 1028   159.1  186.7     0.0  175.6              11.3            989.6
# 1029   260.9  100.5    78.3  200.6               8.6            864.5
#
#       FineAggregate  Age  CSinMPa
# 0             676.0   28    79.99
# 1             676.0   28    61.89
# 2             594.0  270    40.27
# 3             594.0  365    41.05
# 4             825.5  360    44.30
# ...             ...  ...      ...
# 1025          768.3   28    44.28
# 1026          813.4   28    31.18
# 1027          780.0   28    23.70
# 1028          788.9   28    32.77
# 1029          761.5   28    32.40
#
# [1030 rows x 9 columns]>

# %%
fig=sns.pairplot(data,height=2.0, aspect=1.8, 
                plot_kws={'edgecolor': 'k', 'linewidth': 1.0},
                diag_kind='kde', diag_kws={'shade': True})

# %%
plt.figure(figsize=(12,12),facecolor='white')
plotnumber=1
for column in data.columns:
    plt.subplot(3,3,plotnumber)
    sns.distplot(data[column])
    plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
x = data.drop('CSinMPa', axis=1)

# %%
x
# Out:
#       Cement   Slag  Flyash  Water  SuperPlasticizer  CoarseAggregate  \
# 0      540.0    0.0     0.0  162.0               2.5           1040.0
# 1      540.0    0.0     0.0  162.0               2.5           1055.0
# 2      332.5  142.5     0.0  228.0               0.0            932.0
# 3      332.5  142.5     0.0  228.0               0.0            932.0
# 4      198.6  132.4     0.0  192.0               0.0            978.4
# ...      ...    ...     ...    ...               ...              ...
# 1025   276.4  116.0    90.3  179.6               8.9            870.1
# 1026   322.2    0.0   115.6  196.0              10.4            817.9
# 1027   148.5  139.4   108.6  192.7               6.1            892.4
# 1028   159.1  186.7     0.0  175.6              11.3            989.6
# 1029   260.9  100.5    78.3  200.6               8.6            864.5
#
#       FineAggregate  Age
# 0             676.0   28
# 1             676.0   28
# 2             594.0  270
# 3             594.0  365
# 4             825.5  360
# ...             ...  ...
# 1025          768.3   28
# 1026          813.4   28
# 1027          780.0   28
# 1028          788.9   28
# 1029          761.5   28
#
# [1030 rows x 8 columns]

# %%
y = data['CSinMPa']

# %%
y
# Out:
# 0       79.99
# 1       61.89
# 2       40.27
# 3       41.05
# 4       44.30
#         ...
# 1025    44.28
# 1026    31.18
# 1027    23.70
# 1028    32.77
# 1029    32.40
# Name: CSinMPa, Length: 1030, dtype: float64

# %%
for column in x.columns:
    x[column]+=1
    x[column]= np.log(x[column])

# %%
x
# Out:
#         Cement      Slag    Flyash     Water  SuperPlasticizer  \
# 0     6.293419  0.000000  0.000000  5.093750          1.252763
# 1     6.293419  0.000000  0.000000  5.093750          1.252763
# 2     5.809643  4.966335  0.000000  5.433722          0.000000
# 3     5.809643  4.966335  0.000000  5.433722          0.000000
# 4     5.296315  4.893352  0.000000  5.262690          0.000000
# ...        ...       ...       ...       ...               ...
# 1025  5.625461  4.762174  4.514151  5.196285          2.292535
# 1026  5.778271  0.000000  4.758749  5.283204          2.433613
# 1027  5.007296  4.944495  4.696837  5.266311          1.960095
# 1028  5.075799  5.234845  0.000000  5.173887          2.509599
# 1029  5.567963  4.620059  4.373238  5.306286          2.261763
#
#       CoarseAggregate  FineAggregate       Age
# 0            6.947937       6.517671  3.367296
# 1            6.962243       6.517671  3.367296
# 2            6.838405       6.388561  5.602119
# 3            6.838405       6.388561  5.902633
# 4            6.886940       6.717200  5.888878
# ...               ...            ...       ...
# 1025         6.769757       6.645481  3.367296
# 1026         6.707962       6.702452  3.367296
# 1027         6.795034       6.660575  3.367296
# 1028         6.898311       6.671906  3.367296
# 1029         6.763307       6.636603  3.367296
#
# [1030 rows x 8 columns]

# %%
plt.figure(figsize=(12,12),facecolor='white')
plotnumber = 1
for column in x.columns:
    plt.subplot(3,3,plotnumber)
    sns.distplot(x[column])
    plt.xlabel(column, fontsize=13)
    plotnumber+=1
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(12,12),facecolor='white')
plotnumber=1
for column in x.columns:
    plt.subplot(3,3,plotnumber)
    sns.boxplot(x[column])
    plt.xlabel(column)
    plotnumber+=1
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(12,12),facecolor='white')
plotnumber=1
for column in x.columns:
    plt.subplot(3,3,plotnumber)
    sns.scatterplot(x[column],y)
    plt.xlabel(column)
    plotnumber+=1
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,6),facecolor='white')
sns.heatmap(x.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train
# Out:
#        Cement      Slag    Flyash     Water  SuperPlasticizer  \
# 196  5.276583  0.000000  4.620059  5.115596          2.140066
# 631  5.786897  0.000000  0.000000  5.220356          0.000000
# 81   5.767696  5.363637  0.000000  5.054333          2.727853
# 526  5.886104  2.995732  4.955827  5.043425          2.476538
# 830  5.093750  5.252273  5.003946  5.192957          2.995732
# ..        ...       ...       ...       ...               ...
# 87   5.660527  5.307773  0.000000  4.981550          2.501436
# 330  5.512622  0.000000  4.837075  4.971894          2.564949
# 466  5.253843  0.000000  4.837868  5.121580          2.388763
# 121  6.165418  4.785824  0.000000  5.204556          2.292535
# 860  5.752573  0.000000  4.736198  5.141664          2.397895
#
#      CoarseAggregate  FineAggregate       Age
# 196         6.915128       6.810032  3.367296
# 631         6.969791       6.664409  2.079442
# 81          6.748877       6.781512  1.386294
# 526         6.849066       6.687109  1.386294
# 830         6.732211       6.609349  3.367296
# ..               ...            ...       ...
# 87          6.913340       6.690470  1.386294
# 330         6.991913       6.686984  2.708050
# 466         6.984716       6.684487  4.615121
# 121         6.748877       6.662494  3.367296
# 860         6.830874       6.664409  3.367296
#
# [721 rows x 8 columns]

# %%
x_test
# Out:
#        Cement      Slag    Flyash     Water  SuperPlasticizer  \
# 31   5.587249  4.744932  0.000000  5.433722          0.000000
# 109  5.896054  5.247024  0.000000  5.111385          2.533697
# 136  5.968452  5.247024  0.000000  4.989752          3.135494
# 88   5.896054  5.247024  0.000000  5.111385          2.533697
# 918  4.983607  0.000000  5.192957  5.313206          2.197225
# ..        ...       ...       ...       ...               ...
# 250  5.525453  0.000000  4.571613  5.238567          1.871802
# 377  5.932245  0.000000  0.000000  5.373425          0.000000
# 615  5.627621  0.000000  0.000000  5.257495          0.000000
# 9    6.165418  0.000000  0.000000  5.433722          0.000000
# 357  5.628340  4.593098  3.238678  5.085743          2.501436
#
#      CoarseAggregate  FineAggregate       Age
# 31          6.838405       6.508769  5.902633
# 109         6.851925       6.629099  2.079442
# 136         6.851925       6.629099  3.367296
# 88          6.851925       6.629099  1.386294
# 918         6.715383       6.768493  3.367296
# ..               ...            ...       ...
# 250         6.864743       6.759487  2.708050
# 377         6.912245       6.637782  4.043051
# 615         6.876265       6.753438  5.198497
# 9           6.838405       6.388561  3.367296
# 357         6.968568       6.663771  4.043051
#
# [309 rows x 8 columns]

# %%
y_train
# Out:
# 196    25.72
# 631    17.54
# 81     25.20
# 526    23.64
# 830    33.76
#        ...
# 87     24.40
# 330    42.22
# 466    33.56
# 121    68.30
# 860    38.46
# Name: CSinMPa, Length: 721, dtype: float64

# %%
y_test
# Out:
# 31     52.91
# 109    55.90
# 136    74.50
# 88     35.30
# 918    10.54
#        ...
# 250    24.92
# 377    36.30
# 615    32.33
# 9      39.29
# 357    66.82
# Name: CSinMPa, Length: 309, dtype: float64

# %%
scalar = StandardScaler()

# %%
X_train = scalar.fit(x_train)

# %%
X_train = scalar.transform(x_train)

# %%
X_test = scalar.transform(x_test)

# %%
X_train= pd.DataFrame(X_train,columns=x_train.columns)

# %%
X_train
# Out:
#        Cement      Slag    Flyash     Water  SuperPlasticizer  \
# 0   -0.775786 -1.059842  1.087816 -0.732865          0.609990
# 1    0.529909 -1.059842 -0.866631  0.159575         -1.235750
# 2    0.480779  1.160607 -0.866631 -1.254755          1.116938
# 3    0.783739  0.180337  1.229857 -1.347679          0.900187
# 4   -1.243583  1.114505  1.250213 -0.073834          1.347976
# ..        ...       ...       ...       ...               ...
# 716  0.206576  1.137481 -0.866631 -1.874789          0.921661
# 717 -0.171855 -1.059842  1.179621 -1.957041          0.976439
# 718 -0.833969 -1.059842  1.179957 -0.681884          0.824484
# 719  1.498394  0.921403 -0.866631  0.024978          0.741490
# 720  0.442085 -1.059842  1.136947 -0.510796          0.832360
#
#      CoarseAggregate  FineAggregate       Age
# 0           0.446070       1.557137  0.083653
# 1           1.120282       0.189325 -1.091401
# 2          -1.604481       1.289248 -1.723837
# 3          -0.368739       0.402538 -1.723837
# 4          -1.810041      -0.327842  0.083653
# ..               ...            ...       ...
# 716         0.424012       0.434106 -1.723837
# 717         1.393135       0.401367 -0.517851
# 718         1.304375       0.377911  1.222184
# 719        -1.604481       0.171336  0.083653
# 720        -0.593120       0.189325  0.083653
#
# [721 rows x 8 columns]

# %%
X_test= pd.DataFrame(X_test,columns=x_test.columns)

# %%
X_test
# Out:
#        Cement      Slag    Flyash     Water  SuperPlasticizer  \
# 0    0.019086  0.904475 -0.866631  1.977220         -1.235750
# 1    0.809198  1.112332 -0.866631 -0.768734          0.949485
# 2    0.994435  1.112332 -0.866631 -1.804914          1.468516
# 3    0.809198  1.112332 -0.866631 -0.768734          0.949485
# 4   -1.525397 -1.059842  1.330172  0.950556          0.659288
# ..        ...       ...       ...       ...               ...
# 304 -0.139025 -1.059842  1.067322  0.314718          0.378621
# 305  0.901797 -1.059842 -0.866631  1.463555         -1.235750
# 306  0.122383 -1.059842 -0.866631  0.475963         -1.235750
# 307  1.498394 -1.059842 -0.866631  1.977220         -1.235750
# 308  0.124223  0.841618  0.503443 -0.987179          0.921661
#
#      CoarseAggregate  FineAggregate       Age
# 0          -0.500233      -1.272573  2.396927
# 1          -0.333474      -0.142336 -1.091401
# 2          -0.333474      -0.142336  0.083653
# 3          -0.333474      -0.142336 -1.723837
# 4          -2.017590       1.166969  0.083653
# ..               ...            ...       ...
# 304        -0.175376       1.082378 -0.517851
# 305         0.410513      -0.060777  0.700221
# 306        -0.033273       1.025557  1.754464
# 307        -0.500233      -2.401663  0.083653
# 308         1.105203       0.183332  0.700221
#
# [309 rows x 8 columns]

# %%
print(X_train.mean())
# Out:
# Cement             -6.428823e-16
# Slag               -2.149614e-16
# Flyash             -4.188359e-17
# Water               2.161778e-15
# SuperPlasticizer   -1.445908e-16
# CoarseAggregate    -8.273240e-15
# FineAggregate      -6.888387e-15
# Age                 1.093285e-16
# dtype: float64

# %%
print(X_train.var())
# Out:
# Cement              1.001389
# Slag                1.001389
# Flyash              1.001389
# Water               1.001389
# SuperPlasticizer    1.001389
# CoarseAggregate     1.001389
# FineAggregate       1.001389
# Age                 1.001389
# dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.svm import SVR, LinearSVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor, RandomForestRegressor

# %%
models = {
    "                     Linear Regression" : LinearRegression(),
    "                 L2 (Ridge) Regression" : Ridge(),
    "Support Vector Machine (Linear Kernel)" : LinearSVR(),
    "   Support Vector Machine (RBF Kernel)" : SVR(),
    "                         Decision Tree" : DecisionTreeRegressor(),
    "                        Neural Network" : MLPRegressor(),
    "                         Random Forest" : RandomForestRegressor(),
    "                     Gradient Boosting" : GradientBoostingRegressor(),
    "                              AdaBoost" : AdaBoostRegressor()
}

# %%
for name,model in models.items():
    model.fit(X_train,y_train)
    print('model trained with. {}'.format(name))
# Out:
# model trained with.                      Linear Regression
# model trained with.                  L2 (Ridge) Regression
# model trained with. Support Vector Machine (Linear Kernel)
# model trained with.    Support Vector Machine (RBF Kernel)
# model trained with.                          Decision Tree
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# model trained with.                         Neural Network
# model trained with.                          Random Forest
# model trained with.                      Gradient Boosting
# model trained with.                               AdaBoost

# %%
from sklearn.metrics import r2_score

# %%
for name, model in models.items():
    y_pred = model.predict(X_test)
    score = r2_score(y_test,y_pred)
    print(score)
# Out:
# 0.7957031494706376
# 0.7956527573152303
# 0.7943404783372902
# 0.7748426106102166
# 0.8214170447126916
# 0.7724667311080359
# 0.886999318838054
# 0.8915536894848282
# 0.782114769622207

# %%
best_model = GradientBoostingRegressor()
best_model.fit(X_train,y_train)
y_pred = best_model.predict(X_test)
score = r2_score(y_test,y_pred)
print ('score before hyperparameter tuning {}'.format(score))
# Out:
# score before hyperparameter tuning 0.8907291075165766

# %%
param = {
    'learning_rate' : [0.01, 0.1, 1.0],
    'n_estimators' : [100, 150, 200],
    'max_depth' : [3, 4, 5]
}

# %%
clf = GridSearchCV(estimator=best_model,param_grid=param)
clf.fit(X_train,y_train)
#best_accuracy = clf.best_score_
best_param = clf.best_params_

# %%
#print("Best Accuracy: {:.2f} %".format(best_accuracy*100))
print(best_param)
# Out:
# {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 200}

# %%
y_pred = clf.predict(X_test)
score = r2_score(y_test,y_pred)
print ('score after hyperparameter tuning {}'.format(score))
# Out:
# score after hyperparameter tuning 0.9220798294893015
